# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
import pandas as pd

from sentence_transformers import SentenceTransformer

from src.duplicate_detector import DuplicateDetector

# %%
df = pd.read_csv("../data/processed/reports_clean.csv")

df.head()
# Out:
#    report_id  group_id                       description
# 0          1         1          حفرة في شارع عباس العقاد
# 1          2         1     يوجد حفرة في شارع عباس العقاد
# 2          3         1  بلاغ عن حفرة في شارع عباس العقاد
# 3          4         1   تم رصد حفرة في شارع عباس العقاد
# 4          5         2   كسر ماسورة مياه في شارع الطيران

# %%
model = SentenceTransformer(
    "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
)

# %%
embeddings = model.encode(
    df["description"].tolist(),
    show_progress_bar=True
)
# Out:
# Batches:   0%|          | 0/13 [00:00<?, ?it/s]

# %%
detector = DuplicateDetector(
    model,
    embeddings,
    df
)

# %%
result = detector.check_duplicate(
    "يوجد حفرة كبيرة أمام البنك الأهلي في شارع عباس العقاد"
)

print(result)
# Out:
# {'duplicate': np.True_, 'similarity': 0.8583279848098755, 'matched_report': 'يوجد حفرة في شارع عباس العقاد'}
