# %%
import pandas as pd

df = pd.read_csv("../data/raw/reports.csv")

df.head()
# Out:
#    report_id  group_id                       description
# 0          1         1          حفرة في شارع عباس العقاد
# 1          2         1     يوجد حفرة في شارع عباس العقاد
# 2          3         1  بلاغ عن حفرة في شارع عباس العقاد
# 3          4         1   تم رصد حفرة في شارع عباس العقاد
# 4          5         2   كسر ماسورة مياه في شارع الطيران

# %%
print(df.shape)
# Out:
# (400, 3)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   report_id    400 non-null    int64
#  1   group_id     400 non-null    int64
#  2   description  400 non-null    str
# dtypes: int64(2), str(1)
# memory usage: 32.8 KB

# %%
df.isnull().sum()
# Out:
# report_id      0
# group_id       0
# description    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv(
    "../data/processed/reports_clean.csv",
    index=False,
    encoding="utf-8-sig"
)
